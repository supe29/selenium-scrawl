# %%
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\kaust'

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys

# %%
driver = webdriver.Chrome('./chromedriver')

# %%
driver = webdriver.Chrome('./chromedriver')
driver.get("http://www.google.com")
time.sleep(3) # open a new chrome page
search_bar = driver.find_element_by_name("q")
time.sleep(3)# search where is located the search bar from google
search_bar.send_keys("getting started with python")
time.sleep(3)# write "getting started with python" on google
search_bar.send_keys(Keys.RETURN) # click enter
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_19600/2032806740.py in <module>
#       1 driver = webdriver.Chrome('./chromedriver')
#       2 driver.get("http://www.google.com")
# ----> 3 time.sleep(3) # open a new chrome page
#       4 search_bar = driver.find_element_by_name("q")
#       5 time.sleep(3)# search where is located the search bar from google
#
# NameError: name 'time' is not defined

# %%
# !pip install selenium
# Out:
# Requirement already satisfied: selenium in c:\users\kaust\anaconda3\lib\site-packages (3.141.0)
# Requirement already satisfied: urllib3 in c:\users\kaust\anaconda3\lib\site-packages (from selenium) (1.26.7)

# %%
driver = webdriver.Chrome('./chromedriver')
driver.get("http://www.google.com")
time.sleep(3) # open a new chrome page
search_bar = driver.find_element_by_name("q")
time.sleep(3)# search where is located the search bar from google
search_bar.send_keys("getting started with python")
time.sleep(3)# write "getting started with python" on google
search_bar.send_keys(Keys.RETURN) # click enter
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_19600/2032806740.py in <module>
#       1 driver = webdriver.Chrome('./chromedriver')
#       2 driver.get("http://www.google.com")
# ----> 3 time.sleep(3) # open a new chrome page
#       4 search_bar = driver.find_element_by_name("q")
#       5 time.sleep(3)# search where is located the search bar from google
#
# NameError: name 'time' is not defined

# %%
import time

# %%
driver = webdriver.Chrome('./chromedriver')
driver.get("https://www.amazon.fr/")
time.sleep(3) # open a new chrome page
search_bar = driver.find_element_by_name("field-keywords")
time.sleep(3)# search where is located the search bar from google
search_bar.send_keys("ps4")
time.sleep(3)# write "getting started with python" on google
search_bar.send_keys(Keys.RETURN) # click enter

# %%
driver.find_element_by_class_name("LC20lb DKV0Md")
driver.click()
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# <ipython-input-13-f0072c9b10c0> in <module>
# ----> 1 driver.find_element_by_class_name("LC20lb DKV0Md")
#       2 driver.click()
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element_by_class_name(self, name)
#     562             element = driver.find_element_by_class_name('foo')
#     563         """
# --> 564         return self.find_element(by=By.CLASS_NAME, value=name)
#     565
#     566     def find_elements_by_class_name(self, name):
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element(self, by, value)
#     974                 by = By.CSS_SELECTOR
#     975                 value = '[name="%s"]' % value
# --> 976         return self.execute(Command.FIND_ELEMENT, {
#     977             'using': by,
#     978             'value': value})['value']
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#     323                 response.get('value', None))
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"css selector","selector":".LC20lb DKV0Md"}
#   (Session info: chrome=90.0.4430.212)

# %%
pip install dash-bootstrap-components
# Out:
# Requirement already satisfied: dash-bootstrap-components in c:\users\kaust\anaconda3\lib\site-packages (0.12.2)
# Requirement already satisfied: dash>=1.9.0 in c:\users\kaust\anaconda3\lib\site-packages (from dash-bootstrap-components) (2.0.0)
# Requirement already satisfied: plotly>=5.0.0 in c:\users\kaust\anaconda3\lib\site-packages (from dash>=1.9.0->dash-bootstrap-components) (5.3.1)
# Requirement already satisfied: dash-table==5.0.0 in c:\users\kaust\anaconda3\lib\site-packages (from dash>=1.9.0->dash-bootstrap-components) (5.0.0)
# Requirement already satisfied: flask-compress in c:\users\kaust\anaconda3\lib\site-packages (from dash>=1.9.0->dash-bootstrap-components) (1.9.0)
# Requirement already satisfied: dash-core-components==2.0.0 in c:\users\kaust\anaconda3\lib\site-packages (from dash>=1.9.0->dash-bootstrap-components) (2.0.0)
# Requirement already satisfied: dash-html-components==2.0.0 in c:\users\kaust\anaconda3\lib\site-packages (from dash>=1.9.0->dash-bootstrap-components) (2.0.0)
# Requirement already satisfied: Flask>=1.0.4 in c:\users\kaust\anaconda3\lib\site-packages (from dash>=1.9.0->dash-bootstrap-components) (1.1.2)
# Note: you may need to restart the kernel to use updated packages.Requirement already satisfied: itsdangerous>=0.24 in c:\users\kaust\anaconda3\lib\site-packages (from Flask>=1.0.4->dash>=1.9.0->dash-bootstrap-components) (2.0.1)
# Requirement already satisfied: click>=5.1 in c:\users\kaust\anaconda3\lib\site-packages (from Flask>=1.0.4->dash>=1.9.0->dash-bootstrap-components) (8.0.3)
# Requirement already satisfied: Jinja2>=2.10.1 in c:\users\kaust\anaconda3\lib\site-packages (from Flask>=1.0.4->dash>=1.9.0->dash-bootstrap-components) (2.11.3)
# Requirement already satisfied: Werkzeug>=0.15 in c:\users\kaust\anaconda3\lib\site-packages (from Flask>=1.0.4->dash>=1.9.0->dash-bootstrap-components) (2.0.2)
#
# Requirement already satisfied: colorama in c:\users\kaust\anaconda3\lib\site-packages (from click>=5.1->Flask>=1.0.4->dash>=1.9.0->dash-bootstrap-components) (0.4.4)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\kaust\anaconda3\lib\site-packages (from Jinja2>=2.10.1->Flask>=1.0.4->dash>=1.9.0->dash-bootstrap-components) (1.1.1)
# Requirement already satisfied: six in c:\users\kaust\anaconda3\lib\site-packages (from plotly>=5.0.0->dash>=1.9.0->dash-bootstrap-components) (1.16.0)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\kaust\anaconda3\lib\site-packages (from plotly>=5.0.0->dash>=1.9.0->dash-bootstrap-components) (8.0.1)
# Requirement already satisfied: brotli in c:\users\kaust\anaconda3\lib\site-packages (from flask-compress->dash>=1.9.0->dash-bootstrap-components) (1.0.9)

# %%
selenium scroll up and down google..?
# Out:
#   File "C:\Users\kaust\AppData\Local\Temp/ipykernel_19600/729250241.py", line 1
#     selenium scroll up and down google..?
#              ^
# SyntaxError: invalid syntax
